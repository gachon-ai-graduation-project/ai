# %%
from openai import OpenAI
import sys

# %%
GEMINI_API_KEY = "AIzaSyB8nlYAFR8a4kf3R8ARRQ_gg2KaBWmdqqo"
GEMINI_API_URL = "https://generativelanguage.googleapis.com/v1beta/openai"

LLM_ID = "gemini-2.0-flash-lite"

client = OpenAI(
    base_url=GEMINI_API_URL,
    api_key=GEMINI_API_KEY,
)

def ai_chat(messages):
    print(f"GEMINI API 호출, models: {LLM_ID}")
    response = client.chat.completions.create(
        model=LLM_ID,
        messages=messages,
        temperature=0.5,
        max_tokens=1000
    )
    return response.choices[0].message.content

word_list = ['운동선수', '과로', '친구', '쓰러지다']
formatted_word_list = ', '.join([f"'{word}'" for word in word_list])


messages = [
    
]
question = f"다음 단어는 수어를 글로스로 인식한 결과입니다. 글로스를 조합해서 문장을 만들어주세요. 답변으로는 문장만 전달해주세요.: {formatted_word_list}"
print(question)
# question = ' '.join(sys.argv[1:])
print(f"질문: {question}")
messages.append({"role": "user", "content": question})
response = ai_chat(messages)
print("답변",response)
# Out:
# 다음 단어는 수어를 글로스로 인식한 결과입니다. 글로스를 조합해서 문장을 만들어주세요. 답변으로는 문장만 전달해주세요.: '운동선수', '과로', '친구', '쓰러지다'
# 질문: 다음 단어는 수어를 글로스로 인식한 결과입니다. 글로스를 조합해서 문장을 만들어주세요. 답변으로는 문장만 전달해주세요.: '운동선수', '과로', '친구', '쓰러지다'
# GEMINI API 호출, models: gemini-2.0-flash-lite
# 답변 운동선수 친구가 과로로 쓰러졌다.
